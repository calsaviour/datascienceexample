# %%
## Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-4657b62d5e13> in <module>()
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 import matplotlib.pyplot as plt
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.py in <module>()
#      96
#      97 from matplotlib.backends import pylab_setup
# ---> 98 _backend_mod, new_figure_manager, draw_if_interactive, _show = pylab_setup()
#      99
#     100
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/__init__.pyc in pylab_setup()
#      26     # imports. 0 means only perform absolute imports.
#      27     backend_mod = __import__(backend_name,
# ---> 28                              globals(),locals(),[backend_name],0)
#      29
#      30     # Things we pull in from all backends
#
# /usr/lib/pymodules/python2.7/matplotlib/backends/backend_tkagg.py in <module>()
#       6 import os.path
#       7
# ...

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0     1
# 1     3
# 2     5
# 3   NaN
# 4     6
# 5     8
# dtype: float64

# %%
import csv
f=open("../../example/data/coal_prod_cleaned.csv")
for row in csv.reader(f):
    print(row)
# Out:
# ['MSHA_ID', 'Average_Employees', 'Company_Type', 'Labor_Hours', 'Mine_Basin', 'Mine_County', 'Mine_Name', 'Mine_State', 'Mine_Status', 'Mine_Type', 'Operating_Company', 'Operating_Company_Address', 'Operation_Type', 'Production_short_tons', 'Union_Code', 'Year']
# ['102838', '4.0', 'Independent Producer Operator', '2712.0', 'Appalachia Southern', 'Bibb', 'Hebron Mine', 'Alabama', 'Permanently abandoned', 'Surface', 'Birmingham Coal & Coke Company', '2477 Valleydale Rd. S. B3, Birmingham, AL 35244', 'Mine only', '10572.0', '', '2002']
# ['103184', '5.0', 'Independent Producer Operator', '2480.0', 'Appalachia Southern', 'Fayette', 'Berry Mine', 'Alabama', 'Temporarily closed', 'Surface', 'Midas Coal Company Incorporate', '401 10th Avenue, S. E, Cullman, AL 35055', 'Mine only', '9725.0', '', '2002']
# ...

# %%
import os
cwd = os.getcwd()
print cwd
